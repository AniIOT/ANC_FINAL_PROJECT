# %%
# %matplotlib inline

# %%
import pandas as pd

# %%
data = pd.read_csv('Sensor_record_20220409_183645_AndroSensor.csv',sep=';', engine='python')

# %%
data
# Out:
#       ACCELEROMETER X (m/s²)  ACCELEROMETER Y (m/s²)  ACCELEROMETER Z (m/s²)  \
# 0                     3.5450                 -1.6642                  6.8910
# 1                     5.4718                 -4.9038                  8.5472
# 2                     7.6155                 -5.0602                  9.4259
# 3                     9.8375                 -2.2454                  9.6667
# 4                    10.8174                 -0.7675                  8.2726
# ...                      ...                     ...                     ...
# 1313                  1.1219                  5.6100                  8.0653
# 1314                 -2.5146                  6.8683                  8.0342
# 1315                 -1.9029                  6.6882                  6.8862
# 1316                 -2.4227                  6.9826                  6.6096
# 1317                 -2.3372                  7.0301                  5.7855
#
# ...

# %%
for i in range(3):
    data.drop(data.columns[3], axis=1, inplace=True)

# %%
for i in range(2):
    data.drop(data.columns[6], axis=1, inplace=True)

# %%
new_header = data.iloc[0] #grab the first row for the header
data = data[1:] #take the data less the header row
data.columns = new_header #set the header row as the df header

# %%
data.drop(data.index[1024:data.shape[0]])
# Out:
# 0      3.5450  -1.6642   6.8910  -1.2360  -3.1367   0.0426
# 1      5.4718  -4.9038   8.5472  -2.1584  -2.8953   0.3885
# 2      7.6155  -5.0602   9.4259  -2.2623  -1.9091   1.2344
# 3      9.8375  -2.2454   9.6667  -1.3594  -0.4714   1.0227
# 4     10.8174  -0.7675   8.2726  -0.9212   0.3715   0.8147
# 5     13.8278   1.5915   1.7554   0.1788  -0.7287   0.5966
# ...       ...      ...      ...      ...      ...      ...
# 1020   1.8182   5.3504   7.8646   0.1735  -0.0852  -0.3283
# 1021  -0.0144   4.5921   8.4972  -0.2297   0.5159  -0.2307
# 1022   0.7735   5.5484   8.6288   0.3744  -0.4273  -0.0681
# 1023   0.6778   4.6463   9.7457  -0.0224   0.1958  -0.0837
# 1024   0.0640   4.5473   8.5412  -0.0484   0.0809   0.0808
#
# [1024 rows x 6 columns]

# %%
import numpy as np

# %%
np.savetxt(r'E:\Arizona\Assignments\SEM-2\EEE-511\Datasets\Dataset #9\001_Aniruddha\1.txt', data.values, fmt='%f')
